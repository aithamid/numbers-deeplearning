# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers,models,Input,preprocessing 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.datasets import mnist

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Load the dataset
# ## a) Keras mnist dataset
# The keras library has a pre-implemented dataset for the mnist images.
# The `load_data` function already splits the data in train and test sets.

# %%
# Load the mnist data
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape) # train set, 60 000 entries
print(x_test.shape) # test set, 10 000 entries
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# (60000, 28, 28)
# (10000, 28, 28)

# %% [markdown]
# ## b) Data augmentation
# Enriching a dataset is a good way of optimizing a model's performance.
# Data-augmentation is a concept in which more data is generated from an existing set.
# As described in [Chris Deotte's post](https://www.kaggle.com/code/cdeotte/25-million-images-0-99757-mnist), the mnist dataset can be augmented by manipulating the data through subtle transformations of rotation, scaling and translation.

# %%
# Normalize the data
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Reshape inputs for data generation
x_train = x_train.reshape((x_train.shape[0], 28, 28, 1))

# Convert labels to one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Data augmentation generator
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# Initialize the data generator
datagen.fit(x_train)
datagen_generator = datagen.flow(x_train, y_train, batch_size=32)

# %%
# The number of images to generate
augment_size = 100000
x_augmented = np.zeros((augment_size, 28, 28, 1))
y_augmented = np.zeros((augment_size, 10))

# Accumulator for the number of samples processed
data_processed = 0

# Generate augmented data
while data_processed < augment_size:
    x_batch, y_batch = next(datagen_generator)
    batch_size = x_batch.shape[0]

    if data_processed + batch_size > augment_size:
        batch_size = data_processed + batch_size - augment_size
                
        x_augmented[data_processed:data_processed+batch_size] = x_batch[:batch_size]
        y_augmented[data_processed:data_processed+batch_size] = y_batch[:batch_size]
    else:
        x_augmented[data_processed:data_processed+batch_size] = x_batch
        y_augmented[data_processed:data_processed+batch_size] = y_batch
    
    data_processed += batch_size

# Remove channel dimension for training
x_train = np.concatenate([x_train, x_augmented])
y_train = np.concatenate([y_train, y_augmented])

# Resizing the output for the train
x_train = x_train.reshape((x_train.shape[0], 28, 28))

print(x_train.shape)
print(y_train.shape)
# Out:
# (160000, 28, 28)
# (160000, 10)

# %% [markdown]
# # 2. Model implementation
# The keras library makes it really easy to implement convolutional neural network.
# One of the most popular choices for handwritten digits recognition neural networks is Yann Lecun's LeNet-5 architecture.

# %%
model = models.Sequential([
        # Input Layer
        layers.Input(shape=(28, 28, 1)),
        
        # C1 Convolutional Layer
        layers.Conv2D(filters=6, kernel_size=(5, 5), activation='relu', padding='same'),
        
        # S2 Pooling Layer
        layers.AvgPool2D(pool_size=(2, 2), strides=2),
        
        # C3 Convolutional Layer
        layers.Conv2D(filters=16, kernel_size=(5, 5), activation='relu'),
        
        # S4 Pooling Layer
        layers.AvgPool2D(pool_size=(2, 2), strides=2),
        
        # C5 Fully Connected Convolutional Layer
        layers.Conv2D(filters=120, kernel_size=(5, 5), activation='relu'),
        
        # Flatten the CNN output to feed it with fully connected layers
        layers.Flatten(),
        
        # F6 Fully Connected Layer
        layers.Dense(units=84, activation='relu'),
        
        # Output Layer with softmax activation for classification
        layers.Dense(units=10, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 6)      │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 14, 14, 6)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 10, 10, 16)     │         2,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 5, 5, 16)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 1, 1, 120)      │        48,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 120)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 84)             │        10,164 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61,706 (241.04 KB)
#  Trainable params: 61,706 (241.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 3. Training

# %%
x_valid = x_train[:10000]
y_valid = y_train[:10000]
x_train = x_train[10000:x_train.shape[0]]
y_train = y_train[10000:y_train.shape[0]]

history = model.fit(
    x_train, y_train,
    epochs=40,
    batch_size=32,
    validation_data=(x_valid, y_valid)
)
# Out:
# Epoch 1/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.8689 - loss: 0.4110 - val_accuracy: 0.9833 - val_loss: 0.0563
# Epoch 2/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9751 - loss: 0.0800 - val_accuracy: 0.9879 - val_loss: 0.0398
# Epoch 3/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9839 - loss: 0.0507 - val_accuracy: 0.9896 - val_loss: 0.0344
# Epoch 4/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9879 - loss: 0.0390 - val_accuracy: 0.9912 - val_loss: 0.0310
# Epoch 5/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9898 - loss: 0.0314 - val_accuracy: 0.9929 - val_loss: 0.0238
# Epoch 6/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9913 - loss: 0.0261 - val_accuracy: 0.9904 - val_loss: 0.0301
# Epoch 7/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9928 - loss: 0.0225 - val_accuracy: 0.9956 - val_loss: 0.0173
# Epoch 8/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9936 - loss: 0.0200 - val_accuracy: 0.9918 - val_loss: 0.0294
# Epoch 9/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9945 - loss: 0.0175 - val_accuracy: 0.9937 - val_loss: 0.0238
# Epoch 10/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9954 - loss: 0.0144 - val_accuracy: 0.9933 - val_loss: 0.0259
# Epoch 11/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9952 - loss: 0.0138 - val_accuracy: 0.9948 - val_loss: 0.0249
# Epoch 12/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9958 - loss: 0.0126 - val_accuracy: 0.9926 - val_loss: 0.0275
# Epoch 13/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9964 - loss: 0.0115 - val_accuracy: 0.9942 - val_loss: 0.0220
# Epoch 14/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9965 - loss: 0.0103 - val_accuracy: 0.9936 - val_loss: 0.0229
# Epoch 15/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9964 - loss: 0.0105 - val_accuracy: 0.9954 - val_loss: 0.0236
# Epoch 16/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9969 - loss: 0.0094 - val_accuracy: 0.9946 - val_loss: 0.0240
# Epoch 17/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9971 - loss: 0.0088 - val_accuracy: 0.9951 - val_loss: 0.0247
# Epoch 18/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9975 - loss: 0.0077 - val_accuracy: 0.9943 - val_loss: 0.0305
# Epoch 19/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9977 - loss: 0.0073 - val_accuracy: 0.9945 - val_loss: 0.0219
# Epoch 20/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9976 - loss: 0.0075 - val_accuracy: 0.9949 - val_loss: 0.0268
# Epoch 21/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9975 - loss: 0.0079 - val_accuracy: 0.9939 - val_loss: 0.0274
# Epoch 22/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9975 - loss: 0.0079 - val_accuracy: 0.9943 - val_loss: 0.0320
# Epoch 23/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9975 - loss: 0.0080 - val_accuracy: 0.9960 - val_loss: 0.0253
# Epoch 24/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9979 - loss: 0.0069 - val_accuracy: 0.9956 - val_loss: 0.0250
# Epoch 25/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9980 - loss: 0.0068 - val_accuracy: 0.9956 - val_loss: 0.0258
# Epoch 26/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9980 - loss: 0.0062 - val_accuracy: 0.9958 - val_loss: 0.0300
# Epoch 27/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9978 - loss: 0.0071 - val_accuracy: 0.9958 - val_loss: 0.0280
# Epoch 28/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9980 - loss: 0.0064 - val_accuracy: 0.9953 - val_loss: 0.0282
# Epoch 29/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9978 - loss: 0.0070 - val_accuracy: 0.9956 - val_loss: 0.0214
# Epoch 30/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9984 - loss: 0.0053 - val_accuracy: 0.9940 - val_loss: 0.0310
# Epoch 31/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9979 - loss: 0.0071 - val_accuracy: 0.9951 - val_loss: 0.0256
# Epoch 32/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9981 - loss: 0.0058 - val_accuracy: 0.9950 - val_loss: 0.0312
# Epoch 33/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9981 - loss: 0.0060 - val_accuracy: 0.9944 - val_loss: 0.0321
# Epoch 34/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9983 - loss: 0.0054 - val_accuracy: 0.9946 - val_loss: 0.0288
# Epoch 35/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9981 - loss: 0.0067 - val_accuracy: 0.9960 - val_loss: 0.0282
# Epoch 36/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9984 - loss: 0.0051 - val_accuracy: 0.9955 - val_loss: 0.0312
# Epoch 37/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9983 - loss: 0.0057 - val_accuracy: 0.9949 - val_loss: 0.0390
# Epoch 38/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9981 - loss: 0.0063 - val_accuracy: 0.9953 - val_loss: 0.0289
# Epoch 39/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9984 - loss: 0.0053 - val_accuracy: 0.9950 - val_loss: 0.0340
# Epoch 40/40
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9987 - loss: 0.0042 - val_accuracy: 0.9959 - val_loss: 0.0274

# %% [markdown]
# # 4. Resulting plots

# %%
history_frame = pd.DataFrame(history.history)
history_frame.loc[:,['loss','val_loss']].plot()
history_frame.loc[:,['accuracy','val_accuracy']].plot()
# Out:
# <Axes: >

# %% [markdown]
# # 5. Testing the model

# %%
# Evaluate the model
loss, accuracy = model.evaluate(x_test, y_test)

print(x_test.shape, y_test.shape)

print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - accuracy: 0.9889 - loss: 0.0657
# (10000, 28, 28) (10000, 10)
# Test Loss: 0.04678252711892128
# Test Accuracy: 0.9912999868392944

# %%
# Predict classes
predictions = model.predict(x_test)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(y_test, axis=1)

# Compute confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# # 6. Saving the model

# %%
model.save('digit_recognizer.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
